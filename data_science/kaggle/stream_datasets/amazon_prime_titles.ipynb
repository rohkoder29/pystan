# %%
import pandas as pd

# %%
df = pd.read_csv("amazon_prime_titles.csv", index_col=False)
df
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %% [markdown]
# Clean data

# %%
# drop non necessary colums
df = df.drop(columns=["show_id"])

# %%
df

# %%
# drop NaNs in rating column (this data will be critical for further analisys)
df = df.loc[df["rating"].notna()]

# %%
df
# Out:
#          type                          title         director  \
# 1       Movie           Take Care Good Night     Girish Joshi
# 16      Movie                       Zoombies     Glenn Miller
# 17    TV Show                     Zoo Babies              NaN
# 18    TV Show  Zoë Coombs Marr: Bossy Bottom              NaN
# 19      Movie                            Zoe    Drake Doremus
# ...       ...                            ...              ...
# 9663    Movie            Pride Of The Bowery  Joseph H. Lewis
# 9664  TV Show                  Planet Patrol              NaN
# 9665    Movie                        Outpost     Steve Barker
# 9666  TV Show        Maradona: Blessed Dream              NaN
# 9667    Movie                    Harry Brown    Daniel Barber
#
#                                                    cast country  \
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India
# 16           Marcus Anderson, Kaiwi Lyman, Andrew Asper     NaN
# ...

# %% [markdown]
# We can see that the column "date_added" has a huge amount of NaNs, so we need to do something about it.

# %%
df.loc[df["date_added"].notna()]
# Out:
#          type                                  title      director  \
# 1       Movie                   Take Care Good Night  Girish Joshi
# 553   TV Show                          The Lucy Show           NaN
# 1089  TV Show                       Scaredy Squirrel           NaN
# 1442  TV Show                                Oddbods           NaN
# 2096  TV Show   Inspector Manara (English Subtitled)           NaN
# ...       ...                                    ...           ...
# 9537  TV Show                            Pan y Circo           NaN
# 9546  TV Show                        Hidden Villages           NaN
# 9635  TV Show  Pokémon the Series: Diamond and Pearl           NaN
# 9642  TV Show                            Lunkerville           NaN
# 9647  TV Show                       Kids In The Hall           NaN
#
#                                                    cast country  \
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India
# ...
