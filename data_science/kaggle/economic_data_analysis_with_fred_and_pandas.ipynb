# %% [markdown]
# ### Economic Data Analysis with FRED & Pandas

# %% [markdown]
# FRED = Federal Reserve Economic Data

# %% [markdown]
# Pull The data, Visualize, discover insights... All with python/pandas!

# %% [markdown]
# To install the Fred API<br>
# `pip install fredapi > /dev/null`

# %% [markdown]
# > #### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline
from fredapi import Fred
fred_key = "3aba83155300c9b03b3877e9b740c2c6"

# %%
pd.set_option("display.max_columns", None)
plt.style.use("fivethirtyeight")
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]

# %% [markdown]
# <hr>

# %% [markdown]
# - Create the Fred Object

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# - Search for economic data from Fred

# %%
fred.search("S&P")
# Out:
#                                 id realtime_start realtime_end  \
# series id
# SP500                        SP500     2022-05-23   2022-05-23
# VXVCLS                      VXVCLS     2022-05-23   2022-05-23
# VXOCLS                      VXOCLS     2022-05-23   2022-05-23
# CSUSHPINSA              CSUSHPINSA     2022-05-23   2022-05-23
# CSUSHPISA                CSUSHPISA     2022-05-23   2022-05-23
# ...                            ...            ...          ...
# RTFPNATZA632NRUG  RTFPNATZA632NRUG     2022-05-23   2022-05-23
# RTFPNAHKA632NRUG  RTFPNAHKA632NRUG     2022-05-23   2022-05-23
# PLXCPPSIA670NRUG  PLXCPPSIA670NRUG     2022-05-23   2022-05-23
# LABSHPESA156NRUG  LABSHPESA156NRUG     2022-05-23   2022-05-23
# GCT1503CA                GCT1503CA     2022-05-23   2022-05-23
#
#                                                               title  \
# series id
# SP500                                                       S&P 500
# ...
