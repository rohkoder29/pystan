# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.style.use("seaborn")
pd.set_option("display.max_columns", None)

# %% [markdown]
# Load the dataset

# %%
dataset = "/home/rohkoder29/Documents/year2022/python/data_science/kaggle/coaster_db.csv"
df = pd.read_csv(dataset, index_col=False)

# %% [markdown]
# ### Information Summary of the Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 56 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   1087 non-null   object
#  1   Length                         953 non-null    object
#  2   Speed                          937 non-null    object
#  3   Location                       1087 non-null   object
#  4   Status                         874 non-null    object
#  5   Opening date                   837 non-null    object
#  6   Type                           1087 non-null   object
#  7   Manufacturer                   1028 non-null   object
#  8   Height restriction             831 non-null    object
#  9   Model                          744 non-null    object
#  10  Height                         965 non-null    object
#  11  Inversions                     932 non-null    float64
# ...

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### Dataset Preparation / Cleaning

# %% [markdown]
# > Drop non crucial columns [Create a subset]

# %%
df.head(1)
# Out:
#          coaster_name          Length             Speed      Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)  Coney Island
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
#
#          Model        Height  Inversions Lift/launch system Cost Trains  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN    NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
#
#   Fast Lane available Replaced            Track layout Fastrack available  \
# 0                 NaN      NaN  Gravity pulled coaster                NaN
#
#   Soft opening date.1 Closing date Opened Replaced by Website  \
# ...

# %%
# list all columns then keep the ones we want
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df = df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 
    # 'Opening date', 'Type', 
       'Manufacturer', 
    #    'Height restriction', 'Model', 'Height',
    #    'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #    'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #    'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #    'Track layout', 'Fastrack available', 'Soft opening date.1',
    #    'Closing date', 'Opened', 'Replaced by', 'Website',
    #    'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #    'Single rider line available', 'Restraint Style',
    #    'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 
       'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 
    #    'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #    'height_value', 'height_unit', 
       'height_ft', 'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    object
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 110.5+ KB

# %%
df.head(1)
# Out:
#          coaster_name      Location   Status            Manufacturer  \
# 0  Switchback Railway  Coney Island  Removed  LaMarcus Adna Thompson
#
#    year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 0             1884    40.574    -73.978      Wood         1884-06-16
#
#    speed_mph  height_ft  Inversions_clean  Gforce_clean
# 0        6.0        NaN                 0           2.9

# %% [markdown]
# > Correct columns data types

# %%
# "opening_date_clean" to datetime data type
df["opening_date_clean"] = pd.to_datetime(df["opening_date_clean"], format="%Y-%m-%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    datetime64[ns]
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 110.5+ KB

# %% [markdown]
# > Also we maybe want to accomodate the columns name

# %%
df.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
def rename_columns(column: str) -> str:
    return column.title()

# %%
df = df.rename(str.title, axis="columns")
# well, we still need to remove the "_clean" suffix
df = df.rename(columns={"Opening_Date_Clean": "Opening_Date",
                   "Inversions_Clean": "Inversions",
                   "Gforce_Clean": "Gforce"})

# %%
df.head(1)
# Out:
#          Coaster_Name      Location   Status            Manufacturer  \
# 0  Switchback Railway  Coney Island  Removed  LaMarcus Adna Thompson
#
#    Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# 0             1884    40.574    -73.978      Wood   1884-06-16        6.0
#
#    Height_Ft  Inversions  Gforce
# 0        NaN           0     2.9

# %% [markdown]
# > let's identify possible duplicated values

# %%
df.loc[df.duplicated(subset=["Coaster_Name"])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %% [markdown]
# Let's look closer to see why those values are labelled as dups

# %%
df.query("Coaster_Name == 'Derby Racer'")
# Out:
#    Coaster_Name      Location   Status    Manufacturer  Year_Introduced  \
# 14  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1911
# 60  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1937
#
#     Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# 14     42.42    -70.986      Wood   1911-01-01        NaN        NaN
# 60     42.42    -70.986      Wood   1911-01-01        NaN        NaN
#
#     Inversions  Gforce
# 14           0     NaN
# 60           0     NaN

# %%
df.query("Coaster_Name == 'Zippin Pippin'")
# Out:
#       Coaster_Name Location Status       Manufacturer  Year_Introduced  \
# 16   Zippin Pippin    Other    NaN  The Gravity Group             1912
# 858  Zippin Pippin    Other    NaN  The Gravity Group             2011
#
#      Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# 16        NaN        NaN      Wood          NaT       40.0        NaN
# 858       NaN        NaN      Wood          NaT       40.0        NaN
#
#      Inversions  Gforce
# 16            0     NaN
# 858           0     NaN

# %%
df.query("Coaster_Name == 'Crystal Beach Cyclone'")
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_Ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %% [markdown]
# - So, as per these three examples above we can see that all values are the same except for the `Year_Introduced` column where we notice differences, which is quite non coherent because the `Opening_Date` remains the same. Then what we're going to do is keep only the first time the coaster was introduced.

# %%
# we gonna drop all dups based on the following columns
df.loc[df.duplicated(subset=["Coaster_Name", "Location", "Opening_Date"])].head()
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# ...

# %%
# and make the inverse our new dataframe
df = df.loc[~df.duplicated(subset=["Coaster_Name", "Location", "Opening_Date"])] \
    .reset_index(drop=True).copy()

# %%
df.loc[df["Coaster_Name"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, Latitude, Longitude, Type_Main, Opening_Date, Speed_Mph, Height_Ft, Inversions, Gforce]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 990 entries, 0 to 989
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Coaster_Name     990 non-null    object
#  1   Location         990 non-null    object
#  2   Status           844 non-null    object
#  3   Manufacturer     932 non-null    object
#  4   Year_Introduced  990 non-null    int64
#  5   Latitude         783 non-null    float64
#  6   Longitude        783 non-null    float64
#  7   Type_Main        990 non-null    object
#  8   Opening_Date     807 non-null    datetime64[ns]
#  9   Speed_Mph        850 non-null    float64
#  10  Height_Ft        159 non-null    float64
#  11  Inversions       990 non-null    int64
#  12  Gforce           324 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 100.7+ KB

# %% [markdown]
# - We can notice that we now have 990 rows and which are unique coasters (by name at least).

# %% [markdown]
# > Now, finally, let's deal with those many missing values

# %% [markdown]
# <hr>

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# > Let's consider the `Year_Introduced` series

# %%
# how many coasters introduced by year
df["Year_Introduced"].value_counts().head(10)
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
# 2008    27
# 2004    25
# 2011    24
# 2007    24
# 2013    23
# Name: Year_Introduced, dtype: int64

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph',
#        'Height_Ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
fig1 = df["Year_Introduced"].value_counts() \
    .head(10) \
    .plot(kind="bar", title="Top 10 Years by amout of Coasters Introduced")
fig1.set_xlabel("Year Introduced")
fig1.set_ylabel("Number of Coasters")
# Out:
# Text(0, 0.5, 'Number of Coasters')

# %% [markdown]
# Let's visualize the distribution regarding :

# %% [markdown]
# - the speed of a coaster

# %%
fig2 = df["Speed_Mph"].plot(kind="hist", 
                            bins=20, 
                            title="Coaster Speed Distribution")
fig2.set_xlabel("Speed (mph)")
fig2.set_ylabel("Coasters Count")
# Out:
# Text(0, 0.5, 'Coasters Count')

# %% [markdown]
# - the height of a coaster

# %%
fig3 = df["Height_Ft"].plot(kind="hist", 
                            bins=20, 
                            title="Coaster Height Distribution")
fig3.set_xlabel("Height (ft)")
fig3.set_ylabel("Coasters Count")
# Out:
# Text(0, 0.5, 'Coasters Count')

# %% [markdown]
# - coaster gforce

# %% [markdown]
# - coaster inversions

# %% [markdown]
# - coaster maiden material

# %% [markdown]
# <hr>

# %% [markdown]
# too bee continuuuued...
