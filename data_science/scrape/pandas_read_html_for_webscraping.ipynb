# %% [markdown]
# ## **Using pandas read_html to Web Scrape Data for Data Science**

# %% [markdown]
# ### **URL to the webpage "2018-19 NBA Player Stats: Per Game"**

# %% [markdown]
# ### Method 1
#
# We could modularize the URL and year strings of text that may be useful for programmatic access (in the subsequent code cell).

# %%
# The Building Blocks
year = '2022'
url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
url
# Out:
# 'https://www.basketball-reference.com/leagues/NBA_2022_per_game.html'

# %% [markdown]
# Now, let's programmatically return a list of URL given a list of years (e.g. 2015,2016,2017,2018,2019).

# %%
years = [2015,2016,2017,2018,2019]
url = f'https://www.basketball-reference.com/leagues/NBA_{years}_per_game.html'

for year in years:
  print(url)

# %% [markdown]
# Method 2

# %%
# direct url
url = 'https://www.basketball-reference.com/leagues/NBA_2019_per_game.html'

# %% [markdown]
# ## **Read HTML webpage into pandas**

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Using pd.read_html() function to read HTML webpage

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [      Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
#  0      1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  ...  .595
#  1      2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  ...  .543
#  2      3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  ...  .753
#  3      4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  ...  .625
#  4      5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  ...  .873
#  ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
#  837  601     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  ...  .481
#  838  602         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  ...  .904
#  839  603     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  ...  .623
#  840  604        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  ...  .776
#  841  605        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  ...  .727
#
#       ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
#  0    2.0  4.5   6.5  1.1  0.5  0.6  1.2  2.1   9.1
#  1    4.6  5.4  10.0  3.4  0.9  0.8  1.5  2.0   6.9
#  2    2.4  7.6  10.1  3.4  1.4  0.8  2.6  3.1  19.1
#  3    1.0  1.7   2.7  0.7  0.2  0.3  0.5  1.1   4.1
#  4    1.6  3.9   5.5  0.9  0.3  1.0  0.9  1.7  12.9
#  ..   ...  ...   ...  ...  ...  ...  ...  ...   ...
#  837  1.5  2.9   4.4  1.7  1.2  0.4  0.8  1.7   6.3
#  838  0.7  3.1   3.7  9.7  0.9  0.1  4.0  1.7  28.4
#  839  1.5  3.7   5.3  0.9  0.3  0.4  0.7  1.5   5.3
#  840  1.9  2.8   4.6  0.8  0.3  0.2  0.7  2.1   5.2
#  841  2.9  5.6   8.5  1.6  0.5  1.0  1.5  2.7  10.3
#
#  [842 rows x 30 columns]]

# %% [markdown]
# ### How many tables are there in the webpage?

# %%
len(df)
# Out:
# 1

# %% [markdown]
# ### Select the first table

# %%
df[0]
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%   3P  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  23.6  3.6   8.3  .439  0.8
# 1      2       Steven Adams   C  28  MEM  76  75  26.3  2.8   5.1  .547  0.0
# 2      3        Bam Adebayo   C  24  MIA  56  56  32.6  7.3  13.0  .557  0.0
# 3      4       Santi Aldama  PF  21  MEM  32   0  11.3  1.7   4.1  .402  0.2
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  22.3  5.4   9.7  .550  0.3
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0  18.3  2.6   5.5  .465  0.7
# 838  602         Trae Young  PG  23  ATL  76  76  34.9  9.4  20.3  .460  3.1
# 839  603     Omer Yurtseven   C  23  MIA  56  12  12.6  2.3   4.4  .526  0.0
# 840  604        Cody Zeller   C  29  POR  27   0  13.1  1.9   3.3  .567  0.0
# 841  605        Ivica Zubac   C  24  LAC  76  76  24.4  4.1   6.5  .626  0.0
#
#      3PA   3P%   2P   2PA   2P%  eFG%   FT  FTA   FT%  ORB  DRB   TRB  AST  \
# 0    2.1  .359  2.9   6.1  .468  .486  1.1  1.8  .595  2.0  4.5   6.5  1.1
# 1    0.0  .000  2.8   5.0  .548  .547  1.4  2.6  .543  4.6  5.4  10.0  3.4
# 2    0.1  .000  7.3  12.9  .562  .557  4.6  6.1  .753  2.4  7.6  10.1  3.4
# 3    1.5  .125  1.5   2.6  .560  .424  0.6  1.0  .625  1.0  1.7   2.7  0.7
# 4    1.0  .304  5.1   8.8  .578  .566  1.9  2.2  .873  1.6  3.9   5.5  0.9
# ..   ...   ...  ...   ...   ...   ...  ...  ...   ...  ...  ...   ...  ...
# 837  1.7  .395  1.9   3.9  .495  .524  0.5  1.0  .481  1.5  2.9   4.4  1.7
# 838  8.0  .382  6.3  12.3  .512  .536  6.6  7.3  .904  0.7  3.1   3.7  9.7
# 839  0.2  .091  2.3   4.2  .547  .528  0.7  1.1  .623  1.5  3.7   5.3  0.9
# 840  0.1  .000  1.9   3.2  .593  .567  1.4  1.8  .776  1.9  2.8   4.6  0.8
# 841  0.0   NaN  4.1   6.5  .626  .626  2.2  3.0  .727  2.9  5.6   8.5  1.6
#
#      STL  BLK  TOV   PF   PTS
# 0    0.5  0.6  1.2  2.1   9.1
# 1    0.9  0.8  1.5  2.0   6.9
# 2    1.4  0.8  2.6  3.1  19.1
# 3    0.2  0.3  0.5  1.1   4.1
# 4    0.3  1.0  0.9  1.7  12.9
# ..   ...  ...  ...  ...   ...
# 837  1.2  0.4  0.8  1.7   6.3
# 838  0.9  0.1  4.0  1.7  28.4
# 839  0.3  0.4  0.7  1.5   5.3
# 840  0.3  0.2  0.7  2.1   5.2
# 841  0.5  1.0  1.5  2.7  10.3
#
# [842 rows x 30 columns]

# %%
df_year = df[0]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We can see that the table header is presented multiple times in several rows.

# %%
df_year[df_year["Age"] == 'Age']
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA  \
# 26   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 49   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 74   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 103  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 130  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 157  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 184  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 212  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 249  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 272  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 297  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 329  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 361  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 391  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 420  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 450  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 479  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 504  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 531  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 560  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 585  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 606  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 633  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 661  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 691  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 728  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 757  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 782  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 809  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
# 834  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  FG%  3P  3PA  3P%  2P  2PA
#
#      2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 26   2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 49   2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 74   2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 103  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 130  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 157  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 184  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 212  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 249  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 272  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 297  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 329  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 361  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 391  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 420  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 450  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 479  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 504  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 531  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 560  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 585  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 606  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 633  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 661  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 691  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 728  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 757  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 782  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 809  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS
# 834  2P%  eFG%  FT  FTA  FT%  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS

# %%
len(df_year[df_year["Age"] == 'Age'])
# Out:
# 30

# %%
df = df_year.drop(df_year[df_year["Age"] == 'Age'].index)

# %%
df.shape
# Out:
# (812, 30)

# %% [markdown]
# ## Quick Exploratory Data Analysis

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Making the histogram

# %%
sns.distplot(df.PTS, 
             kde=False)
# Out:
# /home/rohkoder29/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PTS'>

# %% [markdown]
# Change bar line color

# %%
sns.distplot(df.PTS, 
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2))
# Out:
# <AxesSubplot:xlabel='PTS'>

# %% [markdown]
# Change bar fill colors

# %%
sns.distplot(df.PTS,
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2),
             color='#00BFC4')
# Out:
# <AxesSubplot:xlabel='PTS'>
